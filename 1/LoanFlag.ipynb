# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Beautiful format for float type
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
card = pd.read_csv('tj_01_creditcard_card.csv')
customer = pd.read_csv('tj_01_creditcard_customer.csv')
transaction = pd.read_csv('tj_01_creditcard_transaction.csv')

training = pd.read_csv('tj_01_training.csv')
test = pd.read_csv('tj_01_test.csv')

# %%
card.head()
customer.head()
# Out:
#             card_no  bill_cyc               pos_dt      cst_id  \
# 0  1234000000023349        20  2017-02-23 00:00:00  1000004674
# 1  1234000000007292        17  2017-02-23 00:00:00  1000010084
# 2  1234000000018889        20  2017-02-23 00:00:00  1000009114
# 3  1234000000016887        17  2017-02-23 00:00:00  1000013313
# 4  1234000000026997        17  2017-02-23 00:00:00  1000010235
#
#                open_dt  exp_dt  cr_lmt_amt  prev_cr_lmt_amt
# 0  2010-12-20 00:00:00    1220     70000.0              0.0
# 1  2014-06-04 00:00:00     619     69000.0          60000.0
# 2  2014-01-22 00:00:00     119     27000.0          32000.0
# 3  2015-12-03 00:00:00    1220     41000.0              0.0
# 4  2014-06-24 00:00:00     619     50000.0          60000.0
#        cst_id  incm_amt   age  main_zip_cd  cr_line_amt               pos_dt
# 0  1000001115     47676  41.0        11110     100000.0  2017-02-23 00:00:00
# ...

# %%
card.info()
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11875 entries, 0 to 11874
# Data columns (total 8 columns):
# card_no            11875 non-null int64
# bill_cyc           11875 non-null int64
# pos_dt             11875 non-null object
# cst_id             11875 non-null int64
# open_dt            11875 non-null object
# exp_dt             11875 non-null int64
# cr_lmt_amt         11875 non-null float64
# prev_cr_lmt_amt    11875 non-null float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 742.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 6 columns):
# cst_id         9544 non-null int64
# incm_amt       9544 non-null int64
# age            9543 non-null float64
# main_zip_cd    9544 non-null int64
# cr_line_amt    9544 non-null float64
# pos_dt         9544 non-null object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 447.5+ KB

# %%
card.describe()
customer.describe()
# Out:
#                    card_no  bill_cyc         cst_id    exp_dt  cr_lmt_amt  \
# count            11875.000 11875.000      11875.000 11875.000   11875.000
# mean  1234000000014096.000    16.536 1000007297.403   664.413  111462.911
# std               8130.275     6.577       4122.280   339.860  113022.282
# min   1234000000000004.000     5.000 1000000002.000   119.000       0.000
# 25%   1234000000007142.500    10.000 1000003727.000   417.000   43000.000
# 50%   1234000000014085.000    17.000 1000007356.000   620.000   78000.000
# 75%   1234000000021072.000    20.000 1000011002.000   921.000  140000.000
# max   1234000000028171.000    25.000 1000013865.000  1221.000 2084780.000
#
#        prev_cr_lmt_amt
# count        11875.000
# mean         60455.887
# std         124010.599
# min              0.000
# 25%              0.000
# 50%              0.000
# 75%          78000.000
# max        2130796.000
#               cst_id    incm_amt      age  main_zip_cd  cr_line_amt
# ...
